# %% [markdown]
# # Welcome to the Capstone project!
#
# Welcome to the final project of the Road to Practitioner (R2P) program. Throughout this program, we have covered many of the essential topics in quantum computing, including variational algorithms, transpilation and error mitigation techniques, and advanced methods such as quantum diagonalization and Hamiltonian simulation. The lectures and the assignments were designed to bring you to the level of a practitioner, which we define as someone capable of executing quantum algorithms independently and reproducing quantum applications at a utility scale.
#
# Now, it's time to put your knowledge into practice! In the Capstone project, we take things a step further by challenging you to reproduce quantum applications at a utility scale for the following applications: quantum optimization, Hamiltonian simulation, and quantum diagonalization. This phase is crucial to complete the program since your ability to apply what you have learned and successfully complete difficult challenges will be evaluated.
# If you pass the Capstone project, you will have demonstrated that you are ready to become a quantum practitioner and tackle new, real-world quantum challenges ahead!

# %% [markdown]
# # Team formation
#
# To solve the challenges you will need to group together with other people and work together as a team (3-4 people per team). The name of the team will be needed during your submission and inserted into the grader at the bottom of this notebook, allowing us to track your progress. When you do this, make sure everyone in your teams spells the team names in the same way (including capitalization) to ensure all scores are collected correctly. There are more details about the grader below.

# %% [markdown]
# # Submission details and deadline
#
# Every member of the team should submit the teams top solution to each challenge (in total: 3 Jupyter notebooks with outputs visible) [here](https://airtable.com/appvmVplmcult6eJ9/pag4TkwAblh0AzYSg/form) before the 6th of July. Include the name of your team and all the names of the team members in the field `Name/Names` as well as your email.

# %% [markdown]
# # Guideline on the challenges and scoring
#
# There are 3 challenges, and each one contributes a certain number of points, which are distributed across its exercises. Most exercises use binary grading, i.e. if you pass you earn the full points for that exercise. However, challenges 1 and 3 also include a final exercise, which is more complex and serves as the culmination of the lab. This exercise is graded in a continuous way, meaning your score depends on the quality of your solution and can range from 0 up to the exercise's maximum. The score for each exercise is indicated in each challenge's notebook.
#
# After the challenge deadline, your team will receive a final score based on the total points accumulated by running the notebooks and passing the graders. There is no limit on the number of attempts to try to pass an exercise. Once you pass an exercise, its grade is saved on our server, so you don't need to worry if you accidentally delete your solution later or overwrite it with a worse score. The grader will store all scores your team submits and return the best cumulative score across the 3 challenges.
#
# Based on your total score, teams are classified into the following categories:
#
#
# ### 🏆 **Grading Scale**
#
# **Maximum Grade:** `300`
#
# | **Score Range** | **Status**       |
# |------------------|------------------|
# | **0 – 100**      | ❌ Not Pass      |
# | **101 – 170**    | ✅ Pass          |
# | **171 – 240**    | 🌟 Well done     |
# | **241 – 300**    | 🏅 Outstanding   |
#
#
#
# The challenges that you will face are the following and they account for 300 points:
#
# > **Note:** that there are no particular order in the challenges and you can complete them in the order that you find more convenient.
#
#
# ### Challenge 1: QMOO (100 points)
#
# **The maximum grade for this exercise is 100 points**
#
# *Summary:*
#
# In this challenge, we will tackle a multi-objective optimization (MOO) problem, reformulated as a weighted Max-Cut problem that can be solved by the Quantum Approximate Optimization Algorithm (QAOA). In particular your task is to to prepare a suitable ansatz for solving the multi-objective Max-cut problem, first for a problem with 42 qubits and then you will be asked to scale it to 80 qubits.
#
# ### Challenge 2: Sample-based Krylov Quantum Diagonalization (100 points)
#
# **The maximum grade for this exercise is 100 points**
#
# *Summary:*
#
# In this challenge, we implement a Sample-based Krylov Quantum Diagonalization (SKQD) workflow to approximate ground states of the transverse-field Ising model and single-impurity Anderson model, executing on IBM Quantum hardware to achieve results comparable to classical exact methods.
#
# ### Challenge 3: Hadron-Schwinger (100 points)
#
# **The maximum grade for this exercise is 100 points**
#
# *Summary:*
#
# In this challenge, we will simulate the propagation of a hadron wavepacket in the Schwinger model on an IBM quantum computer, prepared on a lattice with $L=34$ spatial sites (68 qubits). We will start with initial states already prepared by SC-ADAPT-VQE and perform the time evolution of the Hamiltonian using the Suzuki-Trotter algorithm to evolve the initial states forward in time. The circuits will first be executed on a simulator and later on an IBM quantum computer.

# %% [markdown]
# ## Grading:
#
# All 3 challenges have a maximum score of __100 points__. We use an automatic grader to grade answers. At the bottom of this notebook, enter your team name into the grader. This only needs to be done once. Once this is done, you will see a message like this:

# %% [markdown]
# <div style="text-align:center;">
# <img src="data:image/png;base64,..." width="100%">
# </div>

# %% [markdown]
# After submitting your team name you can begin working on any of the 3 challenges. In each notebook, you will import the grader at the top of the notebook. This is all that is required to get the grader working. As you work through the exercises in the notebook, you will use the grader functions to grade each exercise. An example of a successful answer will look like this:

# %% [markdown]
# <div style="text-align:center;">
# <img src="data:image/png;base64,..." width="100%">
# </div>

# %% [markdown]
# The text output indicates how many points are scored for that exercise. Importantly, all answers are saved in the grader. There is no need to worry about re-executing the grader function and obtaining a lower score.
#
# If you answer an exercise incorrectly, the grader will output a score of 0 and a _hint_ message indicating what went wrong.
#
# Once you finish a notebook, save this notebook separately. Then you can experiment and try and improve your grade. Everytime you obtain a higher score, we recommend saving the notebook (with outputs of grader visible) as you will need to submit your highest scoring notebook at the end via the submission form for us to check.
#
# Participants can work in parallel on their notebooks, the grader will save everyone’s answers. The workload can be split up however you prefer.
#
# _Note_: Participants will be able to see their total grade by using the function `check_progress` (see below).

# %% [markdown]
# # Installation guide (Mac and Linux)
#
# ### Step 1: Create virtual environment.
#
# Please use Python 3.11-3.13. If you do not have one of these versions of Python installed on your machine, please follow the instructions [here](https://www.python.org/downloads/). Then, run the following code in your open terminal to create a new environment:
#
# ```python3 -m venv r2p-venv```
#
# Then activate the environment:
#
# ```source r2p-venv/bin/activate```
#
# **Alternative:** If setting up Python or Jupyter locally is difficult, consider using Google Colab or qBraid. See [this guide](https://quantum.cloud.ibm.com/docs/en/guides/online-lab-environments) for details.
#
# ### Step 2: Install required packages.
#
# Finally, install the required packages by running the following line in your open terminal:
#
# ```pip install -r requirements.txt```
#
# **Alternative:** you can also execute the following line in a separate cell on a Jupyter Notebook:
#
# ```%pip install -r "requirements.txt"```

# %% [markdown]
# # Installation guide (Windows)
#
# The challenge 2: (SKQD) needs to use the `ffsim` library which is not supported on Windows.
#
# To run that challenge you NEED to use Google Colab or qBraid. See [this guide](https://quantum.cloud.ibm.com/docs/en/guides/online-lab-environments) for details.
#
# However, if you still want to run the other two challenges (1 and 3) locally you can do it by following these instructions:
#
# ### Step 1: Create virtual environment.
#
# Please use Python 3.11-3.13. If you do not have one of these versions of Python installed on your machine, please follow the instructions [here](https://www.python.org/downloads/). Then, run the following code in your open terminal to create a new environment:
#
# ```python3 -m venv r2p-venv```
#
# Then activate the environment:
#
# ```source r2p-venv/bin/activate```
#
#
# ### Step 2: Install required packages.
#
# Finally, install the required packages by running the following line in your open terminal:
#
# ```pip install -r requirements-windows.txt```
#
# **Alternative:** you can also execute the following line in a separate cell on a Jupyter Notebook:
#
# ```%pip install -r "requirements-windows.txt"```

# %%
# %pip install -r "requirements-windows.txt"
#%pip install -r "requirements.txt"
# Out:
# ...
#   Using cached qopt_best_practices-0.1.0-py3-none-any.whl
# ...
#   Using cached qaoa_training_pipeline-0.1.0-py3-none-any.whl
# ...
#   Using cached qc_grader-2026.6.19-py3-none-any.whl
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Join a team

# %%
from qc_grader.challenges.r2p_2026_canada import join_team
YOUR_TEAM_NAME="Visionary"
join_team(YOUR_TEAM_NAME)
# Out:
# Trying to join "Visionary", please wait...
#
# You have joined "Visionary" 🎉
# Any answers you submit from now on will be associated with this team.

# %% [markdown]
# ## Check your progress
#
# After you join a team, you can check your progress with the following function:

# %%
from qc_grader.challenges.r2p_2026_canada import check_progress
check_progress()
# Out:
# Fetching your progress. Please wait...
#
# 📊 Your progress
#
# Exercises passed: 20/21
# Total score: 231.74796618457975
#
# Lab "lab_skqd" — 5/6 passed, score 70.0
#   ✅ ex1 — score 10.0
#   ✅ ex2 — score 10.0
#   ✅ ex3 — score 20.0
#   ✅ ex4 — score 10.0
#   ✅ ex5 — score 20.0
#   ⬜ ex6 — score 0.0
#
# Lab "lab_hadron" — 11/11 passed, score 95.12230081113562
#   ✅ ex1 — score 5.0
#   ✅ ex2 — score 10.0
#   ✅ ex3 — score 10.0
#   ✅ ex4 — score 15.0
#   ✅ ex5 — score 5.0
#   ✅ ex6 — score 5.0
#   ✅ ex7 — score 5.0
#   ✅ ex8 — score 5.0
#   ✅ ex9 — score 5.0
#   ✅ ex10 — score 5.0
#   ✅ ex11 — score 25.122300811135617
#
# Lab "lab_qmoo" — 4/4 passed, score 66.62566537344414
#   ✅ ex1 — score 10.0
#   ✅ ex2 — score 5.0
#   ✅ ex3 — score 10.0
#   ✅ ex4 — score 41.625665373444136

# %% [markdown]
# You can expect to get an output like this one:

# %% [markdown]
# <div style="text-align:center;">
# <img src="data:image/png;base64,..." width="100%">
# </div>
